# %%
print("Hello World")
# Out:
# Hello World

# %%
num = 10
print(num)
# Out:
# 10

# %%
str = "Moiz Ahmed"
print(str)
# Out:
# Moiz Ahmed

# %%
str = '''Moiz Ahmed'''
print(str)
# Out:
# Moiz Ahmed

# %%
num = 5.9
print(type(num))
# Out:
# <class 'float'>

# %%
num = 12
print(type(num))
# Out:
# <class 'int'>

# %%
x = False
print(type(x))
# Out:
# <class 'bool'>

# %%
a = None
print(type(a))
# Out:
# <class 'NoneType'>

# %%
# sum of two num
# Arithmatice Operaotr 
numOne = 10
numTwo = 5
sum = numOne + numTwo
print(sum)
# Out:
# 15

# %%
# Arithmatice Operaotr 
numOne = 5
numTwo = 2
print(numOne + numTwo)
print(numOne - numTwo)
print(numOne * numTwo)
print(numOne / numTwo)
print(numOne % numTwo)
print(numOne ** numTwo)
# Out:
# 7
# 3
# 10
# 2.5
# 1
# 25

# %%
# Comparision Operator/ Relational Operator
num = 10
numTwo = 5
print(num == numTwo )
print(num != numTwo)
print(num > numTwo)
print(num < numTwo)
print(num <= numTwo)
print(num >= numTwo)
# Out:
# False
# True
# True
# False
# False
# True

# %%
# Assignment Operator
numOne = 10
numTwo = 5
sum = numOne + numTwo
print(sum)

# %%
# Assignment Operator
numOne = 7
numOne += 10
print(numOne)
# Out:
# 17

# %%
numOne = 7
numOne -= 2
print(numOne)
# Out:
# 5

# %%
numOne = 7
numOne *= 2
print(numOne)
# Out:
# 14

# %%
numOne = 7
numOne %= 2
print(numOne)
# Out:
# 1

# %%
numOne = 10
numOne **= 5
print(numOne)
# Out:
# 100000

# %%
a = 30
b = 20
print(not(a > b))
# Out:
# False

# %%
# type casting  string number int/ float main convert nahi hoti
# number convert ho jata hai string main
a = int("2")
b = 4.5
print(type(a))
print(a + b)
# Out:
# <class 'int'>
# 6.5

# %%
a = 3.15
a = str(a)
print(type(a))
# Out:
# <class 'str'>

# %%
a = 1.2
a = str(a)
print(type(a))
# Out:
# <class 'str'>

# %%
# input and output
# input users se jo ata hai oski type hamesha string hoti hai 
# users se input lete waqt type casting ka use hota hai ex int(input("Enter your age"))
name = input("Enter your name")
print("Welcome",name)
print(type(name))
# Out:
# Enter your name Moiz Ahmed
# Welcome Moiz Ahmed
# <class 'str'>

# %%
# Practice Question one
numOne = float(input("Enter a first number"))
numTwo = float(input("Enter a second number"))
sum = (numOne+numTwo)
print(sum)
print(type(sum))
# Out:
# Enter a first number 6.6
# Enter a second number 3
# 9.6
# <class 'float'>

# %%
# Practice Question two
square = float(input("Enter square side"))
side = (square* square)
print(side)
# Out:
# Enter square side 4
# 16.0

# %%
# Practice Question three
valOne = float(input("Enter first value"))
valTwo = float(input("Enter second value"))
avg = (valOne + valTwo) /2 

print("The Average is",avg)
# Out:
# Enter first value 12
# Enter second value 12
# The Average is 12.0

# %%
# Practice Question four
a = int(input("Enter first number"))
b = int(input("Enter second number"))
if a>= b:
    print("True")
else:
    print("False")
# Out:
# Enter first number 10
# Enter second number 2
# True

# %%
#string ki length check python ka builtin funtion hota hai len string ki lenth check karne k liye or yeh space bhi count karta hai
checkLen = "Hello world"
assignLen = len(checkLen)
print(assignLen)
# Out:
# 11

# %%
\n use hota hai next line k liye (escape sequance character)
a = "Hello \n World"
print(a)
# Out:
# Hello
#  World

# %%
# indexing or index hamesha zero se start hota hai 
# index ko hum access kar sakte hain lakin chhange nahi kar sakte oska char\val
name = "Moiz Ahmed"
char = name[0]
print(char)
# Out:
# M
